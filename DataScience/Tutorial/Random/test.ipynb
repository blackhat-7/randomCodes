# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.array([4,2,4,6,8,2,3,44,12,4,1,6,2,4,657,21,335,7,12,2])
X = range(len(y))

# %%
fig, ax = plt.subplots(figsize=(8, 5))
ax.set_facecolor('white')
plt.grid()
ax.plot(X, y, 'b.')
# Out:
# [&lt;matplotlib.lines.Line2D at 0x1206093d0&gt;]
# &lt;Figure size 576x360 with 1 Axes&gt;
