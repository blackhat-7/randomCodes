# %%
# Import all libraries
import math
import random
import numpy as np
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler

# %%
# Creating training Data Set

train_samples = []
train_labels = []

# 5% anomaly
for i in range(50):
  train_samples.append(random.randint(13, 64))
  train_labels.append(0)
  train_samples.append(random.randint(64, 100))
  train_labels.append(1)

# Rest 95% normal
for i in range(1000):
  train_samples.append(random.randint(13, 64))
  train_labels.append(1)
  train_samples.append(random.randint(64, 100))
  train_labels.append(0)

print("Input\tOutput")
for i in range(10):
  print(str(train_samples[i])+"\t"+str(train_labels[i]))
# Out:
# Input	Output
# 14	0
# 66	1
# 13	0
# 90	1
# 25	0
# 79	1
# 58	0
# 97	1
# 63	0
# 94	1

# %%
train_samples = np.array(train_samples)
train_labels = np.array(train_labels)
train_samples, train_labels = shuffle(train_samples, train_labels)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_train_samples = scaler.fit_transform(train_samples.reshape(-1,1))

# %%
print("Input\tOutput")
for i in range(10):
  print(str(scaled_train_samples[i])+"\t"+str(train_labels[i]))
# Out:
# Input	Output
# [0.11494253]	1
# [0.62068966]	1
# [0.86206897]	0
# [0.5862069]	0
# [0.20689655]	1
# [0.88505747]	0
# [0.8045977]	1
# [0.35632184]	1
# [0.56321839]	1
# [0.02298851]	1

# %%
import pandas as pd

# %%
test_data = [1,2,3,4,5]
series_data = pd.Series(test_data)
series_data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
test_data2 = [7,7,2,6,9,2,2,5]
series_data2 = pd.Series(test_data2)
series_data2
# Out:
# 0    7
# 1    7
# 2    2
# 3    6
# 4    9
# 5    2
# 6    2
# 7    5
# dtype: int64

# %%
concat_series = pd.concat((series_data, series_data2), axis=0)
concat_series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# 0    7
# 1    7
# 2    2
# 3    6
# 4    9
# 5    2
# 6    2
# 7    5
# dtype: int64

# %%
data = [[2, 4], [3,9], [4,16], [5,25], [6,36]]
df1 = pd.DataFrame(data, columns=["Numbers", "Squares"])
df1
# Out:
#    Numbers  Squares
# 0        2        4
# 1        3        9
# 2        4       16
# 3        5       25
# 4        6       36

# %%
data2 = [[7, 49], [8, 64], [9, 81]]
df2 = pd.DataFrame(data2, columns=["Numbers", "Squares"])
df2
# Out:
#    Numbers  Squares
# 0        7       49
# 1        8       64
# 2        9       81

# %%
concat_df = pd.concat((df1, df2), axis=0, ignore_index=True)
concat_df
# Out:
#    Numbers  Squares
# 0        2        4
# 1        3        9
# 2        4       16
# 3        5       25
# 4        6       36
# 5        7       49
# 6        8       64
# 7        9       81

# %%
concat_df.plot()

# %%
concat_df.loc[5]
# Out:
# Numbers     7
# Squares    49
# Name: 5, dtype: int64

# %%
concat_df.iloc[5]
# Out:
# Numbers     7
# Squares    49
# Name: 5, dtype: int64
